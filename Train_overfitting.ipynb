# %%
import os
import numpy as np
import torch
from torch import nn
from torch.optim import Adam
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from scipy.spatial.transform import Rotation as R
import time
import pickle
import argparse
from utils import *

from deepVCP import DeepVCP
from CustomDataset2 import CustomDataset2
from deepVCP_loss import deepVCP_loss
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
from tqdm import tqdm

# %%
dataset = 'CustomDataset2'
retrain_path = 'store'
model_path = 'Optimise_final_model.pt'
full_dataset = True

# %%
num_epochs = 20
batch_size = 1
lr = 0.001
# loss balancing factor 
alpha = 0.5

print(f"Params: epochs: {num_epochs}, batch: {batch_size}, lr: {lr}, alpha: {alpha}\n")

# check if cuda is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"device: {device}")
# Out:
# Params: epochs: 20, batch: 1, lr: 0.001, alpha: 0.5
#
# device: cuda

# %%
root = 'meshes/'
train_data= CustomDataset2(root=root)
# Out:
# Processing bun000_v2.ply
# (40245, 3)
# Processing bun045_v2.ply
# (40091, 3)
# Processing bun090_v2.ply
# (30373, 3)
# Processing bun180_v2.ply
# (40247, 3)
# Processing bun270_v2.ply
# (31697, 3)
# Processing bun315_v2.ply
# (35334, 3)
# # Total clouds 6

# %%
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False)

for n_batch, (src, target, R_gt, t_gt, ) in enumerate(train_loader):
    print(src.shape, target.shape)
    print(R_gt, t_gt)
    break


num_train = len(train_data)
print('Train dataset size: ', num_train)

use_normal = dataset == "modelnet"

# Initialize the model
model = DeepVCP(use_normal=use_normal)
if torch.cuda.device_count() > 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    # dim = 0 [30, xxx] -> [10, ...], [10, ...], [10, ...] on 3 GPUs
    model = nn.DataParallel(model)

model.to(device)
# Out:
# torch.Size([1, 3, 10000]) torch.Size([1, 3, 10000])
# tensor([[[ 0.7743, -0.3514,  0.5262],
#          [ 0.4306,  0.9020, -0.0313],
#          [-0.4636,  0.2509,  0.8498]]], dtype=torch.float64) tensor([[[0.0742],
#          [0.0742],
#          [0.0742]]], dtype=torch.float64)
# Train dataset size:  30
# DeepVCP(
#   (FE1): feat_extraction_layer(
#     (sa1): PointNetSetAbstraction(
#       (mlp_convs): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mlp_bns): ModuleList(
#         (0-1): 2 x BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (sa2): PointNetSetAbstraction(
#       (mlp_convs): ModuleList(
#         (0): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mlp_bns): ModuleList(
#         (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (sa3): PointNetSetAbstraction(
#       (mlp_convs): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mlp_bns): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (WL): weighting_layer(
#     (fc1): Sequential(
#       (0): Linear(in_features=32, out_features=16, bias=True)
#       (1): ReLU()
#     )
#     (fc2): Sequential(
#       (0): Linear(in_features=16, out_features=8, bias=True)
#       (1): ReLU()
#     )
#     (fc3): Sequential(
#       (0): Linear(in_features=8, out_features=1, bias=True)
#       (1): Softplus(beta=1, threshold=20)
#     )
#   )
#   (DFE): feat_embedding_layer(
#     (fc1): Linear(in_features=35, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=32, bias=True)
#     (fc3): Linear(in_features=32, out_features=32, bias=True)
#     (max_pool): MaxPool1d(kernel_size=32, stride=32, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cpg): cpg(
#     (conv1): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv2): Conv3d(16, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv3): Conv3d(4, 1, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (softmax): Softmax(dim=-1)
#   )
# )

# %%
optim = Adam(model.parameters(), lr=lr)

# begin train 
model.train()
loss_epoch_avg = []
for epoch in tqdm(range(num_epochs)):
    print(f"epoch #{epoch}")
    loss_epoch = []
    running_loss = 0.0

    for n_batch, (src, target, R_gt, t_gt, ) in enumerate(train_loader):
        start_time = time.time()
        # mini batch
        src, target, R_gt, t_gt = src.to(device), target.to(device), R_gt.to(device), t_gt.to(device)
        t_init = torch.randn((1, 3))
        R_prior = R_gt.clone()
        corruption = torch.FloatTensor(batch_size, 3, 3).uniform_(0.9, 1.1).cuda()
        R_prior = R_prior*corruption
        src_keypts, target_vcp = model(src, target, R_prior, t_init)
        # print('src_keypts shape', src_keypts.shape)
        # print('target_vcp shape', target_vcp.shape)
        # zero gradient 
        optim.zero_grad()
        loss, R_pred, t_pred = deepVCP_loss(src_keypts, target_vcp, R_gt, t_gt, alpha=0.5)


        # error metric for rigid body transformation
        r_pred = R.from_matrix(R_pred.squeeze(0).cpu().detach().numpy())
        r_pred_arr = torch.tensor(r_pred.as_euler('xyz', degrees=True)).reshape(1, 3)
        r_gt = R.from_matrix(R_gt.squeeze(0).cpu().detach().numpy())
        r_gt_arr = torch.tensor(r_gt.as_euler('xyz', degrees=True)).reshape(1, 3)
        pdist = nn.PairwiseDistance(p = 2)
        t_pred = t_pred.squeeze(-1)
        t_gt = t_gt.squeeze(-1)

        print("rotation error: ", pdist(r_pred_arr, r_gt_arr).mean())
        print("translation error: ", pdist(t_pred, t_gt).mean())

        # backward pass
        loss.backward()
        # update parameters 
        optim.step()

        running_loss += loss.item()
        loss_epoch += [loss.item()]
        print("--- %s seconds ---" % (time.time() - start_time))
        if (n_batch + 1) % 5 == 0:
            print("Epoch: [{}/{}], Batch: {}, Loss: {}".format(
                epoch, num_epochs, n_batch, loss.item()))
            running_loss = 0.0

    torch.save(model.state_dict(), "epoch_" + str(epoch) + "_model.pt")
    loss_epoch_avg += [sum(loss_epoch) / len(loss_epoch)]
    print("loss epoch", loss_epoch)
    with open("training_loss_" + str(epoch) + ".txt", "wb") as fp:   #Pickling
        pickle.dump(loss_epoch, fp)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# epoch #0
# feature extraction time:  7.882020473480225
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.013999700546264648
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# c:\Users\bingwang\.conda\envs\InverseCW4\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9579, 8410,  355,  ..., 5979, 3797, 3177], device='cuda:0')
# get_cat_feat_tgt time:  0.100982666015625
# Loss: 0.27637573912479096
# rotation error:  tensor(3.1098, dtype=torch.float64)
# translation error:  tensor(0.4787, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 15.347990989685059 seconds ---
# feature extraction time:  6.659988164901733
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.021999835968017578
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9223, 7081, 3391,  ..., 3105, 7852, 5251], device='cuda:0')
# get_cat_feat_tgt time:  0.09599971771240234
# Loss: 0.27459086797206944
# rotation error:  tensor(1.8495, dtype=torch.float64)
# translation error:  tensor(0.4757, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.901975393295288 seconds ---
# feature extraction time:  6.630988121032715
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999649047851562
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7672, 9124, 2372,  ..., 9800, 8443, 6377], device='cuda:0')
# get_cat_feat_tgt time:  0.09900021553039551
# Loss: 0.2652749522319714
# rotation error:  tensor(3.1689, dtype=torch.float64)
# translation error:  tensor(0.4596, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.42197585105896 seconds ---
# feature extraction time:  6.2989888191223145
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015999794006347656
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4609, 6105, 9579,  ..., 8234, 1057, 1597], device='cuda:0')
# get_cat_feat_tgt time:  0.09799981117248535
# Loss: 0.2606825147270588
# rotation error:  tensor(2.3695, dtype=torch.float64)
# translation error:  tensor(0.4516, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.357976198196411 seconds ---
# feature extraction time:  6.349991083145142
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999814987182617
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9521, 3299, 2418,  ..., 5933, 5157,  191], device='cuda:0')
# get_cat_feat_tgt time:  0.10099983215332031
# Loss: 0.24915880266668983
# rotation error:  tensor(0.7961, dtype=torch.float64)
# translation error:  tensor(0.4316, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.197978734970093 seconds ---
# Epoch: [0/20], Batch: 4, Loss: 0.24915880266668983
# feature extraction time:  6.719988107681274
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01799941062927246
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9106, 8245, 8729,  ..., 4553, 7322, 5239], device='cuda:0')
# get_cat_feat_tgt time:  0.11399960517883301
# Loss: 0.23499054500243122
# rotation error:  tensor(1.7563, dtype=torch.float64)
# translation error:  tensor(0.4068, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.371976375579834 seconds ---
# feature extraction time:  6.617987871170044
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015000104904174805
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6749, 3841, 2417,  ..., 2029, 3243, 9010], device='cuda:0')
# get_cat_feat_tgt time:  0.09999990463256836
# Loss: 0.21185771209261753
# rotation error:  tensor(1.0765, dtype=torch.float64)
# translation error:  tensor(0.3667, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.32297658920288 seconds ---
# feature extraction time:  6.827987909317017
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018000125885009766
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9477, 5561, 7944,  ..., 6959, 3887, 3999], device='cuda:0')
# get_cat_feat_tgt time:  0.10799980163574219
# Loss: 0.1778115809094979
# rotation error:  tensor(0.8722, dtype=torch.float64)
# translation error:  tensor(0.3081, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.713974237442017 seconds ---
# feature extraction time:  6.586987495422363
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015999555587768555
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4760, 3696,  582,  ..., 9374, 1322, 6527], device='cuda:0')
# get_cat_feat_tgt time:  0.0989997386932373
# Loss: 0.1421393383286807
# rotation error:  tensor(2.0391, dtype=torch.float64)
# translation error:  tensor(0.2467, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.209979772567749 seconds ---
# feature extraction time:  6.574987888336182
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999814987182617
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6533, 5738, 9017,  ..., 4715, 8333, 2559], device='cuda:0')
# get_cat_feat_tgt time:  0.09399962425231934
# Loss: 0.0889993066817635
# rotation error:  tensor(3.3984, dtype=torch.float64)
# translation error:  tensor(0.1560, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.545975685119629 seconds ---
# Epoch: [0/20], Batch: 9, Loss: 0.0889993066817635
# feature extraction time:  6.489988565444946
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699972152709961
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010004043579101562
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7949, 9444,  806,  ..., 8380,  436, 7993], device='cuda:0')
# get_cat_feat_tgt time:  0.09648394584655762
# Loss: 0.023345632686382727
# rotation error:  tensor(2.5229, dtype=torch.float64)
# translation error:  tensor(0.0549, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.222983360290527 seconds ---
# feature extraction time:  6.331988334655762
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014999866485595703
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2800, 5307, 6484,  ..., 7469, 8900, 3338], device='cuda:0')
# get_cat_feat_tgt time:  0.10699987411499023
# Loss: 0.046724583807539855
# rotation error:  tensor(3.2182, dtype=torch.float64)
# translation error:  tensor(0.0959, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.902976751327515 seconds ---
# feature extraction time:  6.788987874984741
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.021999835968017578
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5122, 7085, 9284,  ..., 6743, 5265, 7505], device='cuda:0')
# get_cat_feat_tgt time:  0.10799956321716309
# Loss: 0.07894302370666809
# rotation error:  tensor(3.9707, dtype=torch.float64)
# translation error:  tensor(0.1491, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.54097580909729 seconds ---
# feature extraction time:  6.469989538192749
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5281, 9971, 7267,  ..., 6233,  211, 6321], device='cuda:0')
# get_cat_feat_tgt time:  0.10599994659423828
# Loss: 0.08599324252742525
# rotation error:  tensor(1.5451, dtype=torch.float64)
# translation error:  tensor(0.1618, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.086032152175903 seconds ---
# feature extraction time:  6.448031425476074
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015999794006347656
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4707, 3059, 4088,  ..., 4446, 6529, 8858], device='cuda:0')
# get_cat_feat_tgt time:  0.1119999885559082
# Loss: 0.07001036745033014
# rotation error:  tensor(3.1595, dtype=torch.float64)
# translation error:  tensor(0.1359, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.041020393371582 seconds ---
# Epoch: [0/20], Batch: 14, Loss: 0.07001036745033014
# feature extraction time:  6.516988754272461
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699972152709961
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010001659393310547
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1091,  958, 7055,  ..., 3565, 6082, 7383], device='cuda:0')
# get_cat_feat_tgt time:  0.0970008373260498
# Loss: 0.04650262087204836
# rotation error:  tensor(1.9648, dtype=torch.float64)
# translation error:  tensor(0.0998, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.207977294921875 seconds ---
# feature extraction time:  6.583988904953003
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010001659393310547
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9898, 8018, 8644,  ..., 1105, 2902, 9303], device='cuda:0')
# get_cat_feat_tgt time:  0.08299994468688965
# Loss: 0.03056697957241051
# rotation error:  tensor(0.1384, dtype=torch.float64)
# translation error:  tensor(0.0691, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.470977067947388 seconds ---
# feature extraction time:  6.4339892864227295
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699972152709961
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9782, 3096, 2708,  ..., 9345, 6329, 3942], device='cuda:0')
# get_cat_feat_tgt time:  0.08600044250488281
# Loss: 0.012879280736372723
# rotation error:  tensor(1.3956, dtype=torch.float64)
# translation error:  tensor(0.0434, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.200977087020874 seconds ---
# feature extraction time:  6.312068223953247
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6820, 1123, 2349,  ..., 6196, 7064, 4530], device='cuda:0')
# get_cat_feat_tgt time:  0.12061667442321777
# Loss: 0.030200003427221473
# rotation error:  tensor(1.9025, dtype=torch.float64)
# translation error:  tensor(0.0594, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.009647130966187 seconds ---
# feature extraction time:  6.717989206314087
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01900029182434082
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5353, 2859, 8161,  ...,  980, 7925, 1657], device='cuda:0')
# get_cat_feat_tgt time:  0.0970001220703125
# Loss: 0.03698950503026997
# rotation error:  tensor(1.3861, dtype=torch.float64)
# translation error:  tensor(0.0688, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.291059494018555 seconds ---
# Epoch: [0/20], Batch: 19, Loss: 0.03698950503026997
# feature extraction time:  6.567988872528076
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7918, 2710,  190,  ..., 9952, 7563, 6887], device='cuda:0')
# get_cat_feat_tgt time:  0.0820002555847168
# Loss: 0.03331722823426892
# rotation error:  tensor(2.4251, dtype=torch.float64)
# translation error:  tensor(0.0622, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.034165143966675 seconds ---
# feature extraction time:  6.075989246368408
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 659, 1714, 5139,  ..., 9353, 9238, 8481], device='cuda:0')
# get_cat_feat_tgt time:  0.10600042343139648
# Loss: 0.029052321784828555
# rotation error:  tensor(2.8561, dtype=torch.float64)
# translation error:  tensor(0.0582, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.657042741775513 seconds ---
# feature extraction time:  6.512989521026611
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999649047851562
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7233, 1974, 7383,  ..., 9187, 9173, 7145], device='cuda:0')
# get_cat_feat_tgt time:  0.10600018501281738
# Loss: 0.015858979548586206
# rotation error:  tensor(2.5722, dtype=torch.float64)
# translation error:  tensor(0.0413, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.958977222442627 seconds ---
# feature extraction time:  6.495989799499512
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999338150024414
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8454, 5743, 6290,  ..., 5840, 8775, 2634], device='cuda:0')
# get_cat_feat_tgt time:  0.10399961471557617
# Loss: 0.014884321223808186
# rotation error:  tensor(2.9341, dtype=torch.float64)
# translation error:  tensor(0.0398, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.310977458953857 seconds ---
# feature extraction time:  6.450989007949829
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699995994567871
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2892, 5403, 8970,  ..., 6398,   26, 9207], device='cuda:0')
# get_cat_feat_tgt time:  0.10899972915649414
# Loss: 0.021851270979765365
# rotation error:  tensor(2.3186, dtype=torch.float64)
# translation error:  tensor(0.0487, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.979978084564209 seconds ---
# Epoch: [0/20], Batch: 24, Loss: 0.021851270979765365
# feature extraction time:  6.74898886680603
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020999431610107422
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3130, 2592, 9889,  ..., 6672, 8362, 5739], device='cuda:0')
# get_cat_feat_tgt time:  0.10599970817565918
# Loss: 0.021333623316906497
# rotation error:  tensor(2.8434, dtype=torch.float64)
# translation error:  tensor(0.0448, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.683976888656616 seconds ---
# feature extraction time:  6.3669891357421875
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015000343322753906
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4365,  282, 8170,  ..., 5426, 6444, 3131], device='cuda:0')
# get_cat_feat_tgt time:  0.09099936485290527
# Loss: 0.016664632813376223
# rotation error:  tensor(2.3571, dtype=torch.float64)
# translation error:  tensor(0.0359, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.741979122161865 seconds ---
# feature extraction time:  6.403989791870117
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699995994567871
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2318, 3013, 5557,  ..., 9426, 3969, 7175], device='cuda:0')
# get_cat_feat_tgt time:  0.1099996566772461
# Loss: 0.008840720020848191
# rotation error:  tensor(4.1846, dtype=torch.float64)
# translation error:  tensor(0.0242, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.76597809791565 seconds ---
# feature extraction time:  6.1670982837677
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01999974250793457
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9704, 7601,  314,  ..., 1004, 8993, 5487], device='cuda:0')
# get_cat_feat_tgt time:  0.12799978256225586
# Loss: 0.009442559307352234
# rotation error:  tensor(3.5719, dtype=torch.float64)
# translation error:  tensor(0.0204, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.93208646774292 seconds ---
# feature extraction time:  6.429989337921143
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020999431610107422
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
#   5%|▌         | 1/20 [06:38<2:06:17, 398.82s/it]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7602, 5331, 4691,  ..., 9096, 4951, 6647], device='cuda:0')
# get_cat_feat_tgt time:  0.10900020599365234
# Loss: 0.01725959058851028
# rotation error:  tensor(1.6776, dtype=torch.float64)
# translation error:  tensor(0.0325, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.094977378845215 seconds ---
# Epoch: [0/20], Batch: 29, Loss: 0.01725959058851028
# loss epoch [0.27637573912479096, 0.27459086797206944, 0.2652749522319714, 0.2606825147270588, 0.24915880266668983, 0.23499054500243122, 0.21185771209261753, 0.1778115809094979, 0.1421393383286807, 0.0889993066817635, 0.023345632686382727, 0.046724583807539855, 0.07894302370666809, 0.08599324252742525, 0.07001036745033014, 0.04650262087204836, 0.03056697957241051, 0.012879280736372723, 0.030200003427221473, 0.03698950503026997, 0.03331722823426892, 0.029052321784828555, 0.015858979548586206, 0.014884321223808186, 0.021851270979765365, 0.021333623316906497, 0.016664632813376223, 0.008840720020848191, 0.009442559307352234, 0.01725959058851028]
# epoch #1
# feature extraction time:  6.5532615184783936
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.019999980926513672
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9018, 5125, 2604,  ..., 6489, 9145, 6160], device='cuda:0')
# get_cat_feat_tgt time:  0.09999990463256836
# Loss: 0.015304348836430294
# rotation error:  tensor(1.5671, dtype=torch.float64)
# translation error:  tensor(0.0303, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.560558080673218 seconds ---
# feature extraction time:  6.419041633605957
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015999794006347656
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5282, 4945,  531,  ..., 4087, 9079, 3828], device='cuda:0')
# get_cat_feat_tgt time:  0.09212183952331543
# Loss: 0.0110405396049468
# rotation error:  tensor(4.1532, dtype=torch.float64)
# translation error:  tensor(0.0225, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.786154985427856 seconds ---
# feature extraction time:  6.80598783493042
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017000198364257812
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5679,  642, 7895,  ..., 2365, 7764, 2366], device='cuda:0')
# get_cat_feat_tgt time:  0.10813212394714355
# Loss: 0.008237461626192467
# rotation error:  tensor(1.9690, dtype=torch.float64)
# translation error:  tensor(0.0242, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.365746259689331 seconds ---
# feature extraction time:  6.3559887409210205
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017000198364257812
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([  26, 5932,   72,  ..., 8998, 6073, 5944], device='cuda:0')
# get_cat_feat_tgt time:  0.10000014305114746
# Loss: 0.010255235907166406
# rotation error:  tensor(1.5797, dtype=torch.float64)
# translation error:  tensor(0.0270, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.162977695465088 seconds ---
# feature extraction time:  6.714987754821777
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018000364303588867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1251, 5281, 5785,  ..., 3913, 7081, 9388], device='cuda:0')
# get_cat_feat_tgt time:  0.10399961471557617
# Loss: 0.01191419168291328
# rotation error:  tensor(1.8724, dtype=torch.float64)
# translation error:  tensor(0.0246, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.64620304107666 seconds ---
# Epoch: [1/20], Batch: 4, Loss: 0.01191419168291328
# feature extraction time:  6.5509889125823975
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.02200007438659668
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4981, 1988, 4308,  ..., 7903, 2367, 8515], device='cuda:0')
# get_cat_feat_tgt time:  0.10800004005432129
# Loss: 0.0013734941506750975
# rotation error:  tensor(2.2470, dtype=torch.float64)
# translation error:  tensor(0.0055, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.286977767944336 seconds ---
# feature extraction time:  6.702988624572754
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699995994567871
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6476, 6456, 5053,  ..., 8730, 1734, 3054], device='cuda:0')
# get_cat_feat_tgt time:  0.09712100028991699
# Loss: 0.0014994653506217944
# rotation error:  tensor(2.8333, dtype=torch.float64)
# translation error:  tensor(0.0056, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.304352283477783 seconds ---
# feature extraction time:  6.561988592147827
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01800084114074707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009996891021728516
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9395, 3782, 4483,  ..., 6587, 7389, 4741], device='cuda:0')
# get_cat_feat_tgt time:  0.09900021553039551
# Loss: 0.0051812526089602615
# rotation error:  tensor(1.4444, dtype=torch.float64)
# translation error:  tensor(0.0172, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.314976930618286 seconds ---
# feature extraction time:  6.210988521575928
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 203, 6870, 7386,  ..., 1706, 9000, 5270], device='cuda:0')
# get_cat_feat_tgt time:  0.10899949073791504
# Loss: 0.008459169051559181
# rotation error:  tensor(2.1873, dtype=torch.float64)
# translation error:  tensor(0.0226, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.610978841781616 seconds ---
# feature extraction time:  6.384989500045776
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1330, 4562, 3460,  ..., 2760, 6881, 3011], device='cuda:0')
# get_cat_feat_tgt time:  0.10099983215332031
# Loss: 0.005267598864951439
# rotation error:  tensor(3.3943, dtype=torch.float64)
# translation error:  tensor(0.0169, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.23497748374939 seconds ---
# Epoch: [1/20], Batch: 9, Loss: 0.005267598864951439
# feature extraction time:  6.310988903045654
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 509, 7879, 8568,  ..., 1385, 4491, 6962], device='cuda:0')
# get_cat_feat_tgt time:  0.11099982261657715
# Loss: 0.005038349044157623
# rotation error:  tensor(4.4314, dtype=torch.float64)
# translation error:  tensor(0.0121, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.895977020263672 seconds ---
# feature extraction time:  6.423989772796631
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6765, 1536, 5841,  ..., 5654, 8231,  394], device='cuda:0')
# get_cat_feat_tgt time:  0.11500000953674316
# Loss: 0.003981297729960101
# rotation error:  tensor(4.1643, dtype=torch.float64)
# translation error:  tensor(0.0085, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.113012313842773 seconds ---
# feature extraction time:  6.411988735198975
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016000747680664062
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.00099945068359375
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1164, 8029, 2760,  ..., 5782,  756, 9968], device='cuda:0')
# get_cat_feat_tgt time:  0.09900021553039551
# Loss: 0.003440634483102438
# rotation error:  tensor(2.6687, dtype=torch.float64)
# translation error:  tensor(0.0088, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.26997709274292 seconds ---
# feature extraction time:  6.513988256454468
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01600050926208496
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 136, 5052, 3470,  ..., 8173, 7075, 8824], device='cuda:0')
# get_cat_feat_tgt time:  0.09599971771240234
# Loss: 0.0028016310710255177
# rotation error:  tensor(2.9709, dtype=torch.float64)
# translation error:  tensor(0.0096, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.19297742843628 seconds ---
# feature extraction time:  6.561989068984985
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016000032424926758
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010006427764892578
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2534, 2561, 1978,  ..., 8230, 4968, 7128], device='cuda:0')
# get_cat_feat_tgt time:  0.10500001907348633
# Loss: 0.004582461646532388
# rotation error:  tensor(2.1624, dtype=torch.float64)
# translation error:  tensor(0.0103, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.166978120803833 seconds ---
# Epoch: [1/20], Batch: 14, Loss: 0.004582461646532388
# feature extraction time:  6.330036163330078
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4842, 2544, 4658,  ...,   35, 7141, 6576], device='cuda:0')
# get_cat_feat_tgt time:  0.09300017356872559
# Loss: 0.0030136540907688483
# rotation error:  tensor(2.8834, dtype=torch.float64)
# translation error:  tensor(0.0065, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.929025411605835 seconds ---
# feature extraction time:  6.342989206314087
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014999628067016602
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.001001119613647461
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4648, 5652, 4202,  ..., 5341,  743, 1398], device='cuda:0')
# get_cat_feat_tgt time:  0.09799909591674805
# Loss: 0.003946761133154848
# rotation error:  tensor(4.7875, dtype=torch.float64)
# translation error:  tensor(0.0105, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.075977563858032 seconds ---
# feature extraction time:  6.386988401412964
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999099731445312
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5093, 6325, 2203,  ..., 3545, 1900, 1246], device='cuda:0')
# get_cat_feat_tgt time:  0.11900019645690918
# Loss: 0.0047538167705383294
# rotation error:  tensor(3.5648, dtype=torch.float64)
# translation error:  tensor(0.0171, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.100977659225464 seconds ---
# feature extraction time:  6.3969886302948
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016000032424926758
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5439, 9847, 5971,  ..., 2825, 8734, 2022], device='cuda:0')
# get_cat_feat_tgt time:  0.09399986267089844
# Loss: 0.007322645129207055
# rotation error:  tensor(3.6004, dtype=torch.float64)
# translation error:  tensor(0.0176, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.928978443145752 seconds ---
# feature extraction time:  6.575989007949829
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018000125885009766
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9161, 4204, 1035,  ..., 6973, 7512, 5778], device='cuda:0')
# get_cat_feat_tgt time:  0.08600020408630371
# Loss: 0.0055423211646957815
# rotation error:  tensor(1.7963, dtype=torch.float64)
# translation error:  tensor(0.0170, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.273978471755981 seconds ---
# Epoch: [1/20], Batch: 19, Loss: 0.0055423211646957815
# feature extraction time:  7.0769877433776855
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699995994567871
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3880, 9063, 8490,  ..., 4477, 2982, 6199], device='cuda:0')
# get_cat_feat_tgt time:  0.13199949264526367
# Loss: 0.004471231816305722
# rotation error:  tensor(2.5912, dtype=torch.float64)
# translation error:  tensor(0.0107, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.7269766330719 seconds ---
# feature extraction time:  6.348989248275757
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699995994567871
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010001659393310547
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6083, 7436, 1368,  ..., 2059, 7574, 2769], device='cuda:0')
# get_cat_feat_tgt time:  0.11699938774108887
# Loss: 0.005651382989215239
# rotation error:  tensor(1.8897, dtype=torch.float64)
# translation error:  tensor(0.0115, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.182977676391602 seconds ---
# feature extraction time:  7.582987308502197
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015000104904174805
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6839, 9441, 6724,  ..., 9717, 5541, 4319], device='cuda:0')
# get_cat_feat_tgt time:  0.09999942779541016
# Loss: 0.0058678862692299735
# rotation error:  tensor(2.6719, dtype=torch.float64)
# translation error:  tensor(0.0143, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.948974847793579 seconds ---
# feature extraction time:  6.450989007949829
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016001224517822266
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3519, 3527, 1685,  ...,  945, 9361, 6828], device='cuda:0')
# get_cat_feat_tgt time:  0.10400009155273438
# Loss: 0.015039016445238083
# rotation error:  tensor(2.4918, dtype=torch.float64)
# translation error:  tensor(0.0280, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.012977838516235 seconds ---
# feature extraction time:  6.3559887409210205
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999649047851562
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9731, 5717, 2238,  ...,  946, 4089, 5453], device='cuda:0')
# get_cat_feat_tgt time:  0.09399962425231934
# Loss: 0.014906413804787941
# rotation error:  tensor(1.8789, dtype=torch.float64)
# translation error:  tensor(0.0281, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 12.848978281021118 seconds ---
# Epoch: [1/20], Batch: 24, Loss: 0.014906413804787941
# feature extraction time:  6.61198878288269
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016000032424926758
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6844, 7491, 3831,  ..., 3691, 9454, 8031], device='cuda:0')
# get_cat_feat_tgt time:  0.09400033950805664
# Loss: 0.016003594688647056
# rotation error:  tensor(2.0009, dtype=torch.float64)
# translation error:  tensor(0.0295, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.252977848052979 seconds ---
# feature extraction time:  6.510988712310791
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01900005340576172
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009996891021728516
# ...
# get_cat_feat_tgt time:  0.0970003604888916
# Loss: 0.002703543520521084
# rotation error:  tensor(1.9289, dtype=torch.float64)
# translation error:  tensor(0.0107, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.055021047592163 seconds ---
# feature extraction time:  6.780993700027466
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999814987182617
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6152, 4236,  776,  ..., 3213, 6564, 8464], device='cuda:0')
# get_cat_feat_tgt time:  0.10299992561340332
# Loss: 0.0011873903168894318
# rotation error:  tensor(3.2277, dtype=torch.float64)
# translation error:  tensor(0.0015, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.13298749923706 seconds ---
# feature extraction time:  6.65299391746521
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016000032424926758
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009999275207519531
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 318,   71, 1547,  ...,  295, 2247, 1827], device='cuda:0')
# get_cat_feat_tgt time:  0.10400009155273438
# Loss: 0.0034071105618079787
# rotation error:  tensor(2.8120, dtype=torch.float64)
# translation error:  tensor(0.0123, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.452987670898438 seconds ---
# feature extraction time:  7.1759936809539795
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01799941062927246
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010006427764892578
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1283, 5501, 4557,  ..., 9868, 2570, 5422], device='cuda:0')
# get_cat_feat_tgt time:  0.09400010108947754
# Loss: 0.004332734126124681
# rotation error:  tensor(3.2805, dtype=torch.float64)
# translation error:  tensor(0.0137, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.173986911773682 seconds ---
# Epoch: [19/20], Batch: 14, Loss: 0.004332734126124681
# feature extraction time:  6.789993762969971
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.013999700546264648
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8353, 4036, 5359,  ..., 2742, 2401, 8152], device='cuda:0')
# get_cat_feat_tgt time:  0.0989999771118164
# Loss: 0.0048197837961049695
# rotation error:  tensor(2.4372, dtype=torch.float64)
# translation error:  tensor(0.0129, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.57898759841919 seconds ---
# feature extraction time:  6.693994522094727
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01699995994567871
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3822, 7452, 5378,  ..., 8286, 8085, 1244], device='cuda:0')
# get_cat_feat_tgt time:  0.09599995613098145
# Loss: 0.004178005918465734
# rotation error:  tensor(1.3682, dtype=torch.float64)
# translation error:  tensor(0.0094, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.659986972808838 seconds ---
# feature extraction time:  6.588994026184082
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999576568603516
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010004043579101562
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9642,  602, 4623,  ...,  438, 7464, 4559], device='cuda:0')
# get_cat_feat_tgt time:  0.10000014305114746
# Loss: 0.005198554975065161
# rotation error:  tensor(2.1408, dtype=torch.float64)
# translation error:  tensor(0.0100, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.735987663269043 seconds ---
# feature extraction time:  6.53899359703064
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014999866485595703
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010001659393310547
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9719, 9296, 6998,  ..., 7303, 5462,  611], device='cuda:0')
# get_cat_feat_tgt time:  0.0989997386932373
# Loss: 0.003736982744422002
# rotation error:  tensor(3.6556, dtype=torch.float64)
# translation error:  tensor(0.0101, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.541987180709839 seconds ---
# feature extraction time:  6.3799943923950195
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014999866485595703
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2755, 1537, 6839,  ..., 5689, 4323, 9490], device='cuda:0')
# get_cat_feat_tgt time:  0.08700013160705566
# Loss: 0.00774994354935798
# rotation error:  tensor(2.0984, dtype=torch.float64)
# translation error:  tensor(0.0183, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.212987899780273 seconds ---
# Epoch: [19/20], Batch: 19, Loss: 0.00774994354935798
# feature extraction time:  6.691993713378906
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017998933792114258
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1849, 7247, 7767,  ..., 4388, 9749, 3220], device='cuda:0')
# get_cat_feat_tgt time:  0.0950002670288086
# Loss: 0.014612360685828696
# rotation error:  tensor(3.2869, dtype=torch.float64)
# translation error:  tensor(0.0272, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.56698727607727 seconds ---
# feature extraction time:  6.737994432449341
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999649047851562
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0010001659393310547
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 606, 9811, 7666,  ..., 9753, 4520, 5691], device='cuda:0')
# get_cat_feat_tgt time:  0.09900021553039551
# Loss: 0.013487784884382868
# rotation error:  tensor(1.9079, dtype=torch.float64)
# translation error:  tensor(0.0291, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.821987628936768 seconds ---
# feature extraction time:  7.085073232650757
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.023000240325927734
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8050, 2037, 8812,  ..., 1372, 8766, 6496], device='cuda:0')
# get_cat_feat_tgt time:  0.10399985313415527
# Loss: 0.010979972803558294
# rotation error:  tensor(1.6072, dtype=torch.float64)
# translation error:  tensor(0.0240, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.796067237854004 seconds ---
# feature extraction time:  7.137993574142456
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2325, 3368, 8214,  ..., 6722, 7030, 4961], device='cuda:0')
# get_cat_feat_tgt time:  0.08599996566772461
# Loss: 0.004954721990734333
# rotation error:  tensor(0.8506, dtype=torch.float64)
# translation error:  tensor(0.0167, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.104987144470215 seconds ---
# feature extraction time:  6.948993682861328
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01999974250793457
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4491, 1772, 2517,  ..., 1964, 1644, 2229], device='cuda:0')
# get_cat_feat_tgt time:  0.10800004005432129
# Loss: 0.00872707215524754
# rotation error:  tensor(3.3328, dtype=torch.float64)
# translation error:  tensor(0.0187, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.79398775100708 seconds ---
# Epoch: [19/20], Batch: 24, Loss: 0.00872707215524754
# feature extraction time:  6.879993915557861
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.019999980926513672
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8201, 8996, 2697,  ..., 1686,  715,  974], device='cuda:0')
# get_cat_feat_tgt time:  0.08299994468688965
# Loss: 0.01475686653962078
# rotation error:  tensor(1.9940, dtype=torch.float64)
# translation error:  tensor(0.0260, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.041072607040405 seconds ---
# feature extraction time:  6.960994005203247
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999338150024414
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7560, 1763, 7188,  ..., 4542, 3749, 9503], device='cuda:0')
# get_cat_feat_tgt time:  0.0989995002746582
# Loss: 0.011030346882349678
# rotation error:  tensor(1.1795, dtype=torch.float64)
# translation error:  tensor(0.0213, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.2439866065979 seconds ---
# feature extraction time:  7.20699143409729
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.023000240325927734
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1508, 4946, 4248,  ..., 6017, 2229, 2863], device='cuda:0')
# get_cat_feat_tgt time:  0.10100007057189941
# Loss: 0.004586046386826863
# rotation error:  tensor(0.9148, dtype=torch.float64)
# translation error:  tensor(0.0116, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 14.263983488082886 seconds ---
# feature extraction time:  6.903992176055908
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018999814987182617
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7930, 6883, 6699,  ..., 2921, 7994, 5437], device='cuda:0')
# get_cat_feat_tgt time:  0.08999967575073242
# Loss: 0.0022587930553822477
# rotation error:  tensor(0.7985, dtype=torch.float64)
# translation error:  tensor(0.0067, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.880985021591187 seconds ---
# feature extraction time:  6.758992910385132
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017999887466430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# 100%|██████████| 20/20 [2:16:03<00:00, 408.16s/it]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 733, 7868, 3823,  ..., 9569, 8071, 4259], device='cuda:0')
# get_cat_feat_tgt time:  0.1100003719329834
# Loss: 0.010870042277999254
# rotation error:  tensor(2.3333, dtype=torch.float64)
# translation error:  tensor(0.0183, device='cuda:0', dtype=torch.float64, grad_fn=<MeanBackward0>)
# --- 13.630985260009766 seconds ---
# Epoch: [19/20], Batch: 29, Loss: 0.010870042277999254
# loss epoch [0.0024786231472144864, 0.003632966313616842, 0.002870603620226793, 0.0026043047959128326, 0.004516337857406418, 0.00420837519842149, 0.0027043296125505377, 0.004761109324859243, 0.006086536667981743, 0.007174659715140915, 0.00720774022177792, 0.002703543520521084, 0.0011873903168894318, 0.0034071105618079787, 0.004332734126124681, 0.0048197837961049695, 0.004178005918465734, 0.005198554975065161, 0.003736982744422002, 0.00774994354935798, 0.014612360685828696, 0.013487784884382868, 0.010979972803558294, 0.004954721990734333, 0.00872707215524754, 0.01475686653962078, 0.011030346882349678, 0.004586046386826863, 0.0022587930553822477, 0.010870042277999254]

# %%
# save
print("Finished Training")
torch.save(model.state_dict(), model_path)
# Out:
# Finished Training
