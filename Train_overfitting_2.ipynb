# %%
import os
import numpy as np
import torch
from torch import nn
from torch.optim import Adam
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from scipy.spatial.transform import Rotation as R
import time
import pickle
import argparse
from utils import *

from deepVCP import DeepVCP
from CustomDataset2 import CustomDataset2
from deepVCP_loss import deepVCP_loss
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
from tqdm import tqdm

# conda install numpy tqdm matplotlib
# conda install -c anaconda scikit-learn
# conda install pytorch torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install -c conda-forge trimesh

# %%
dataset = 'CustomDataset2'
retrain_path = 'store'
model_path = 'Optimise_final_model.pt'
full_dataset = True

# %%
num_epochs = 20
batch_size = 1
lr = 0.001
# loss balancing factor 
alpha = 0.5

print(f"Params: epochs: {num_epochs}, batch: {batch_size}, lr: {lr}, alpha: {alpha}\n")

# check if cuda is available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"device: {device}")
# Out:
# Params: epochs: 20, batch: 1, lr: 0.001, alpha: 0.5
#
# device: cuda

# %%
root = 'meshes/'
train_data= CustomDataset2(root=root)
# Out:
# Processing bun000_v2.ply
# (40245, 3)
# Processing bun045_v2.ply
# (40091, 3)
# Processing bun090_v2.ply
# (30373, 3)
# Processing bun180_v2.ply
# (40247, 3)
# Processing bun270_v2.ply
# (31697, 3)
# Processing bun315_v2.ply
# (35334, 3)
# # Total clouds 6

# %%
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False)

num_train = len(train_data)
print('Train dataset size: ', num_train)

use_normal = dataset == "modelnet"

# Initialize the model
model = DeepVCP(use_normal=use_normal)
model.load_state_dict(torch.load('./first_train_epoch_19_model.pt', map_location='cuda'))
if torch.cuda.device_count() > 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    # dim = 0 [30, xxx] -> [10, ...], [10, ...], [10, ...] on 3 GPUs
    model = nn.DataParallel(model)

model.to(device)
# Out:
# Train dataset size:  30
# DeepVCP(
#   (FE1): feat_extraction_layer(
#     (sa1): PointNetSetAbstraction(
#       (mlp_convs): ModuleList(
#         (0): Conv2d(3, 16, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mlp_bns): ModuleList(
#         (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (sa2): PointNetSetAbstraction(
#       (mlp_convs): ModuleList(
#         (0): Conv2d(3, 32, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mlp_bns): ModuleList(
#         (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (sa3): PointNetSetAbstraction(
#       (mlp_convs): ModuleList(
#         (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (mlp_bns): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (WL): weighting_layer(
#     (fc1): Sequential(
#       (0): Linear(in_features=32, out_features=16, bias=True)
#       (1): ReLU()
#     )
#     (fc2): Sequential(
#       (0): Linear(in_features=16, out_features=8, bias=True)
#       (1): ReLU()
#     )
#     (fc3): Sequential(
#       (0): Linear(in_features=8, out_features=1, bias=True)
#       (1): Softplus(beta=1, threshold=20)
#     )
#   )
#   (DFE): feat_embedding_layer(
#     (fc1): Linear(in_features=35, out_features=32, bias=True)
#     (fc2): Linear(in_features=32, out_features=32, bias=True)
#     (fc3): Linear(in_features=32, out_features=32, bias=True)
#     (max_pool): MaxPool1d(kernel_size=32, stride=32, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cpg): cpg(
#     (conv1): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv2): Conv3d(16, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv3): Conv3d(4, 1, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (softmax): Softmax(dim=-1)
#   )
# )

# %%
optim = Adam(model.parameters(), lr=lr)

# begin train 
model.train()
loss_epoch_avg = []
for epoch in tqdm(range(num_epochs)):
    print(f"epoch #{epoch}")
    loss_epoch = []
    running_loss = 0.0

    for n_batch, (src, target, R_gt, t_gt, R_prior) in enumerate(train_loader):
        start_time = time.time()
        # mini batch
        src, target, R_gt, t_gt, R_prior = src.to(device), target.to(device), R_gt.to(device), t_gt.to(device), R_prior.to(device)
        t_init = torch.randn((1, 3))
        if epoch < 3:
            src_keypts, target_vcp = model(src, target, R_gt, t_init)
        else:
            src_keypts, target_vcp = model(src, target, R_prior, t_init)
        # print('src_keypts shape', src_keypts.shape)
        # print('target_vcp shape', target_vcp.shape)
        # zero gradient 
        optim.zero_grad()
        loss, R_pred, t_pred = deepVCP_loss(src_keypts, target_vcp, R_gt, t_gt, alpha=0.5)


        # error metric for rigid body transformation
        r_pred = R.from_matrix(R_pred.squeeze(0).cpu().detach().numpy())
        r_pred_arr = torch.tensor(r_pred.as_euler('xyz', degrees=True)).reshape(1, 3)
        r_gt = R.from_matrix(R_gt.squeeze(0).cpu().detach().numpy())
        r_gt_arr = torch.tensor(r_gt.as_euler('xyz', degrees=True)).reshape(1, 3)
        pdist = nn.PairwiseDistance(p = 2)
        t_pred = t_pred.squeeze(-1)
        t_gt = t_gt.squeeze(-1)

        print("rotation error: ", pdist(r_pred_arr, r_gt_arr).item())
        print("translation error: ", pdist(t_pred, t_gt).item())

        # backward pass
        loss.backward()
        # update parameters 
        optim.step()

        running_loss += loss.item()
        loss_epoch += [loss.item()]
        print("--- %s seconds ---" % (time.time() - start_time))
        if (n_batch + 1) % 5 == 0:
            print("Epoch: [{}/{}], Batch: {}, Loss: {}".format(
                epoch, num_epochs, n_batch, loss.item()))
            running_loss = 0.0

    torch.save(model.state_dict(), "train2_epoch_" + str(epoch) + "_model.pt")
    loss_epoch_avg += [sum(loss_epoch) / len(loss_epoch)]
    print("loss epoch", loss_epoch)
    with open("training_loss_" + str(epoch) + ".txt", "wb") as fp:   #Pickling
        pickle.dump(loss_epoch, fp)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# epoch #0
# feature extraction time:  6.514231443405151
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014949798583984375
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# c:\Users\bingwang\.conda\envs\3D\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6647,  331, 5217,  ..., 6068,  710, 5802], device='cuda:0')
# get_cat_feat_tgt time:  0.10564661026000977
# Loss: 0.009534380564656116
# rotation error:  0.5830700465061389
# translation error:  0.018363410093700242
# --- 13.175766229629517 seconds ---
# feature extraction time:  5.948279619216919
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015946626663208008
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009970664978027344
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8939, 2740, 6951,  ..., 3180, 2396, 8850], device='cuda:0')
# get_cat_feat_tgt time:  0.0877070426940918
# Loss: 0.0289460798490175
# rotation error:  0.6156564079201852
# translation error:  0.052914848528045254
# --- 12.233277320861816 seconds ---
# feature extraction time:  6.366838693618774
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793980598449707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1002, 4413, 2183,  ..., 7876, 9407,  731], device='cuda:0')
# get_cat_feat_tgt time:  0.10066342353820801
# Loss: 0.027248642048610047
# rotation error:  0.6378577892640623
# translation error:  0.04973246991088624
# --- 12.946921348571777 seconds ---
# feature extraction time:  5.96339225769043
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018886327743530273
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 360, 9907,  388,  ..., 8342, 2898, 5263], device='cuda:0')
# get_cat_feat_tgt time:  0.10166001319885254
# Loss: 0.01287297203202614
# rotation error:  0.6227076470529195
# translation error:  0.024631421020552016
# --- 12.945003509521484 seconds ---
# feature extraction time:  6.2541749477386475
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016942977905273438
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009970664978027344
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2991, 9777, 1681,  ..., 4296, 2907, 4826], device='cuda:0')
# get_cat_feat_tgt time:  0.08970022201538086
# Loss: 0.009899172638327867
# rotation error:  2.5903066178671224
# translation error:  0.020049211059827095
# --- 12.725160598754883 seconds ---
# Epoch: [0/20], Batch: 4, Loss: 0.009899172638327867
# feature extraction time:  7.1979475021362305
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.019969463348388672
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1069, 2948, 3875,  ..., 5327, 5901, 5497], device='cuda:0')
# get_cat_feat_tgt time:  0.09269022941589355
# Loss: 0.013431346016354597
# rotation error:  0.9091944758936563
# translation error:  0.02448800205677469
# --- 13.31793999671936 seconds ---
# feature extraction time:  6.962793588638306
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01794266700744629
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6069, 7380, 3966,  ..., 4438, 1982, 5290], device='cuda:0')
# get_cat_feat_tgt time:  0.08272337913513184
# Loss: 0.010420513220999437
# rotation error:  1.943143579577789
# translation error:  0.019531369408994907
# --- 13.573325395584106 seconds ---
# feature extraction time:  6.211244106292725
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015946626663208008
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1962, 3863, 1026,  ..., 8313, 3157, 3400], device='cuda:0')
# get_cat_feat_tgt time:  0.0969686508178711
# Loss: 0.0024087996180834
# rotation error:  1.338292817148685
# translation error:  0.006320409431474169
# --- 12.678924322128296 seconds ---
# feature extraction time:  6.458084583282471
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014890909194946289
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1147, 3207, 9880,  ..., 8132, 5867, 2693], device='cuda:0')
# get_cat_feat_tgt time:  0.10465049743652344
# Loss: 0.011687378788191217
# rotation error:  9.297243126622455
# translation error:  0.018955081578833244
# --- 13.263554811477661 seconds ---
# feature extraction time:  6.340425968170166
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.02089381217956543
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5893, 1455, 7592,  ..., 6028, 1781, 4659], device='cuda:0')
# get_cat_feat_tgt time:  0.10595011711120605
# Loss: 0.016439070369957374
# rotation error:  3.5461254436398875
# translation error:  0.029372304113504985
# --- 13.39951753616333 seconds ---
# Epoch: [0/20], Batch: 9, Loss: 0.016439070369957374
# feature extraction time:  6.131741046905518
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793956756591797
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2174, 3927,   30,  ..., 2587, 7322, 4756], device='cuda:0')
# get_cat_feat_tgt time:  0.10564732551574707
# Loss: 0.008711001751530376
# rotation error:  0.5630362888616461
# translation error:  0.017665777931978932
# --- 12.890346765518188 seconds ---
# feature extraction time:  6.295076608657837
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793956756591797
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 336, 1247, 1482,  ..., 8020, 9098, 8912], device='cuda:0')
# get_cat_feat_tgt time:  0.1036539077758789
# Loss: 0.004177744110385644
# rotation error:  0.26231162699712646
# translation error:  0.00984126192635397
# --- 12.784944295883179 seconds ---
# feature extraction time:  6.485328674316406
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.0189363956451416
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1015, 3672, 8882,  ..., 3633, 6412, 4167], device='cuda:0')
# get_cat_feat_tgt time:  0.10465049743652344
# Loss: 0.006483061964839447
# rotation error:  1.9516141966881388
# translation error:  0.013147172920574258
# --- 13.255799055099487 seconds ---
# feature extraction time:  6.336824655532837
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01794290542602539
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1948, 4621,  941,  ..., 8007, 4847,   22], device='cuda:0')
# get_cat_feat_tgt time:  0.12059617042541504
# Loss: 0.009487632056372952
# rotation error:  0.212800784833257
# translation error:  0.021602032139979636
# --- 13.231498003005981 seconds ---
# feature extraction time:  6.595958471298218
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694345474243164
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 427, 5376, 2396,  ..., 3187, 9150, 8257], device='cuda:0')
# get_cat_feat_tgt time:  0.1066436767578125
# Loss: 0.009456632267819357
# rotation error:  1.8504590184822876
# translation error:  0.025254849018308562
# --- 13.222251653671265 seconds ---
# Epoch: [0/20], Batch: 14, Loss: 0.009456632267819357
# feature extraction time:  6.532171010971069
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 238, 6054, 7002,  ..., 3318, 9662, 8662], device='cuda:0')
# get_cat_feat_tgt time:  0.09243011474609375
# Loss: 0.006081971650677381
# rotation error:  6.4715974514816414
# translation error:  0.019551679707249355
# --- 12.840886116027832 seconds ---
# feature extraction time:  6.366796970367432
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940044403076172
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6777, 1278, 9745,  ..., 1691,  481, 4114], device='cuda:0')
# get_cat_feat_tgt time:  0.09767365455627441
# Loss: 0.003864824855263435
# rotation error:  1.091949586221575
# translation error:  0.009301124281783786
# --- 13.030596017837524 seconds ---
# feature extraction time:  6.853294610977173
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940044403076172
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7809, 9063, 9655,  ..., 1539, 8810, 1530], device='cuda:0')
# get_cat_feat_tgt time:  0.07774066925048828
# Loss: 0.007297041967699407
# rotation error:  2.645646966142818
# translation error:  0.015440744334756543
# --- 13.301746129989624 seconds ---
# feature extraction time:  6.373701095581055
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940759658813477
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8303, 5029, 7410,  ..., 6675, 9359, 9224], device='cuda:0')
# get_cat_feat_tgt time:  0.1036536693572998
# Loss: 0.008007611262633786
# rotation error:  0.46662058576095017
# translation error:  0.022611151615169512
# --- 12.775309085845947 seconds ---
# feature extraction time:  5.852443218231201
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793980598449707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7995, 2745, 9336,  ..., 1289, 1609, 8721], device='cuda:0')
# get_cat_feat_tgt time:  0.08671021461486816
# Loss: 0.0068134359512429495
# rotation error:  9.90326960546828
# translation error:  0.02160971914315976
# --- 12.63477897644043 seconds ---
# Epoch: [0/20], Batch: 19, Loss: 0.0068134359512429495
# feature extraction time:  6.703599214553833
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01495051383972168
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2063, 7269, 7367,  ..., 5968, 5008, 6080], device='cuda:0')
# get_cat_feat_tgt time:  0.11162662506103516
# Loss: 0.007914052219588243
# rotation error:  0.8541081272353103
# translation error:  0.017577615720457143
# --- 13.414507627487183 seconds ---
# feature extraction time:  6.852073431015015
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793837547302246
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5812, 1137, 8036,  ..., 6945, 5867, 9302], device='cuda:0')
# get_cat_feat_tgt time:  0.11162734031677246
# Loss: 0.006388018204246524
# rotation error:  1.584893935174729
# translation error:  0.013442056846588328
# --- 14.004143238067627 seconds ---
# feature extraction time:  6.078660726547241
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01807379722595215
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6757, 8740,  702,  ..., 8313,  803, 6516], device='cuda:0')
# get_cat_feat_tgt time:  0.08870339393615723
# Loss: 0.008317267505405845
# rotation error:  1.39548050616819
# translation error:  0.023070626461042635
# --- 12.80646276473999 seconds ---
# feature extraction time:  6.250087738037109
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940521240234375
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5463,  543, 5928,  ..., 5146, 8111, 3701], device='cuda:0')
# get_cat_feat_tgt time:  0.09069705009460449
# Loss: 0.006493826943265621
# rotation error:  1.5078758104367895
# translation error:  0.021395901779352976
# --- 12.710817813873291 seconds ---
# feature extraction time:  6.552132844924927
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940521240234375
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 418,  583, 1850,  ...,  792, 8691, 4145], device='cuda:0')
# get_cat_feat_tgt time:  0.07653260231018066
# Loss: 0.0055944460338889345
# rotation error:  0.6787315440381012
# translation error:  0.012912424027797652
# --- 13.17575979232788 seconds ---
# Epoch: [0/20], Batch: 24, Loss: 0.0055944460338889345
# feature extraction time:  6.749959707260132
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6211, 6695, 7187,  ..., 7533, 9491, 9174], device='cuda:0')
# get_cat_feat_tgt time:  0.1096334457397461
# Loss: 0.011435649886428449
# rotation error:  1.5364509880599302
# translation error:  0.020463945413150303
# --- 13.473358869552612 seconds ---
# feature extraction time:  6.758387088775635
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.02292346954345703
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8320, 4696, 6821,  ..., 7045, 5720, 9443], device='cuda:0')
# get_cat_feat_tgt time:  0.10863661766052246
# Loss: 0.007077000185861772
# rotation error:  0.2968848922915447
# translation error:  0.015152093836162775
# --- 13.75896430015564 seconds ---
# feature extraction time:  6.337867259979248
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016942501068115234
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8245, 5297, 7648,  ..., 3970, 2274, 2290], device='cuda:0')
# get_cat_feat_tgt time:  0.10027694702148438
# Loss: 0.004284646134029807
# rotation error:  1.0332941302579612
# translation error:  0.015337202926840722
# --- 13.048995018005371 seconds ---
# feature extraction time:  5.99394416809082
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694321632385254
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2575, 2555,  592,  ..., 3329,  713, 2425], device='cuda:0')
# get_cat_feat_tgt time:  0.10564684867858887
# Loss: 0.008697478447693942
# rotation error:  1.6684832179328362
# translation error:  0.01853180718962974
# --- 13.18412733078003 seconds ---
# feature extraction time:  6.126798629760742
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01594686508178711
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
#   5%|▌         | 1/20 [06:32<2:04:26, 392.99s/it]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7111, 6671, 8274,  ..., 5871, 7099, 7447], device='cuda:0')
# get_cat_feat_tgt time:  0.08571338653564453
# Loss: 0.011340488127863847
# rotation error:  1.684585901520797
# translation error:  0.025077068109433
# --- 12.881672382354736 seconds ---
# Epoch: [0/20], Batch: 29, Loss: 0.011340488127863847
# loss epoch [0.009534380564656116, 0.0289460798490175, 0.027248642048610047, 0.01287297203202614, 0.009899172638327867, 0.013431346016354597, 0.010420513220999437, 0.0024087996180834, 0.011687378788191217, 0.016439070369957374, 0.008711001751530376, 0.004177744110385644, 0.006483061964839447, 0.009487632056372952, 0.009456632267819357, 0.006081971650677381, 0.003864824855263435, 0.007297041967699407, 0.008007611262633786, 0.0068134359512429495, 0.007914052219588243, 0.006388018204246524, 0.008317267505405845, 0.006493826943265621, 0.0055944460338889345, 0.011435649886428449, 0.007077000185861772, 0.004284646134029807, 0.008697478447693942, 0.011340488127863847]
# epoch #1
# feature extraction time:  6.675664663314819
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3258, 6280, 7010,  ..., 2218, 4840, 7558], device='cuda:0')
# get_cat_feat_tgt time:  0.1036531925201416
# Loss: 0.008218081927973762
# rotation error:  1.8108972449421747
# translation error:  0.015953865173899514
# --- 13.492854118347168 seconds ---
# feature extraction time:  6.767483234405518
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8279, 3714, 9862,  ..., 7461,  182, 7321], device='cuda:0')
# get_cat_feat_tgt time:  0.0847172737121582
# Loss: 0.004211456075801618
# rotation error:  1.2489549441712673
# translation error:  0.008232613632062995
# --- 13.346405267715454 seconds ---
# feature extraction time:  6.438751935958862
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694321632385254
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6587, 2091, 4693,  ..., 4337,  206,  770], device='cuda:0')
# get_cat_feat_tgt time:  0.11262297630310059
# Loss: 0.0033743481419934067
# rotation error:  1.0307907188751537
# translation error:  0.00925729565677685
# --- 13.351797342300415 seconds ---
# feature extraction time:  6.572045564651489
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.021926164627075195
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6750, 8593, 6828,  ..., 7702,  190, 4955], device='cuda:0')
# get_cat_feat_tgt time:  0.09908509254455566
# Loss: 0.007655996853436484
# rotation error:  1.8951030249241074
# translation error:  0.01870522503748671
# --- 12.934637784957886 seconds ---
# feature extraction time:  6.700581073760986
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8538, 5230, 9039,  ..., 4028, 4874, 1439], device='cuda:0')
# get_cat_feat_tgt time:  0.09202885627746582
# Loss: 0.008112031264531635
# rotation error:  2.16803961617582
# translation error:  0.014937470411161271
# --- 13.681951522827148 seconds ---
# Epoch: [1/20], Batch: 4, Loss: 0.008112031264531635
# feature extraction time:  6.130904674530029
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1137, 1399,  394,  ..., 3994, 3111, 2745], device='cuda:0')
# get_cat_feat_tgt time:  0.09169387817382812
# Loss: 0.007811046140674535
# rotation error:  0.7667052220090804
# translation error:  0.016539676045683536
# --- 12.544445514678955 seconds ---
# feature extraction time:  6.808759689331055
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020929813385009766
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2442, 4878, 1805,  ..., 5812, 1030, 8754], device='cuda:0')
# get_cat_feat_tgt time:  0.08882808685302734
# Loss: 0.0041859663373815335
# rotation error:  9.838244208594407
# translation error:  0.01064808704731157
# --- 13.496617555618286 seconds ---
# feature extraction time:  6.364980220794678
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940282821655273
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2962, 6058,  723,  ..., 3242, 1047, 4252], device='cuda:0')
# get_cat_feat_tgt time:  0.10166025161743164
# Loss: 0.006882031127524826
# rotation error:  0.5300310731979224
# translation error:  0.01672554424846556
# --- 12.689419269561768 seconds ---
# feature extraction time:  6.647756814956665
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016942977905273438
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 492, 4981, 1586,  ..., 7915, 6831, 2288], device='cuda:0')
# get_cat_feat_tgt time:  0.08970046043395996
# Loss: 0.008104870044218476
# rotation error:  0.1140035458542077
# translation error:  0.021237551261727838
# --- 13.523750305175781 seconds ---
# feature extraction time:  6.106649160385132
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793980598449707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9238, 7639, 9141,  ...,   10, 6395, 2028], device='cuda:0')
# get_cat_feat_tgt time:  0.09568023681640625
# Loss: 0.00795531342780694
# rotation error:  0.9782693491322416
# translation error:  0.020659645119653052
# --- 13.007308006286621 seconds ---
# Epoch: [1/20], Batch: 9, Loss: 0.00795531342780694
# feature extraction time:  6.412928342819214
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020929574966430664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009968280792236328
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7737, 7817, 1736,  ..., 6733,  902, 4413], device='cuda:0')
# get_cat_feat_tgt time:  0.07752275466918945
# Loss: 0.009281226642050933
# rotation error:  1.228276222231918
# translation error:  0.021587930534683306
# --- 13.843923807144165 seconds ---
# feature extraction time:  6.592137098312378
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.021926403045654297
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6476, 4705, 8357,  ..., 2967, 1208,  203], device='cuda:0')
# get_cat_feat_tgt time:  0.09368634223937988
# Loss: 0.005748528923793285
# rotation error:  1.6340159865024544
# translation error:  0.017069083184462232
# --- 13.591997146606445 seconds ---
# feature extraction time:  6.832354545593262
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793980598449707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3842, 8959,  695,  ..., 9541, 4527, 5485], device='cuda:0')
# get_cat_feat_tgt time:  0.09368634223937988
# Loss: 0.004287760735529958
# rotation error:  2.154944032418607
# translation error:  0.010301980379363408
# --- 13.776385307312012 seconds ---
# feature extraction time:  6.499417543411255
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940044403076172
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1224, 1712, 7793,  ...,  346, 5366, 9833], device='cuda:0')
# get_cat_feat_tgt time:  0.1036529541015625
# Loss: 0.007166221533380425
# rotation error:  1.200986457450737
# translation error:  0.015355315183467699
# --- 13.249852895736694 seconds ---
# feature extraction time:  5.990986108779907
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014950275421142578
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3069,  344, 9294,  ..., 9992, 8948, 5523], device='cuda:0')
# get_cat_feat_tgt time:  0.09169435501098633
# Loss: 0.009639544804104627
# rotation error:  1.0856483394764966
# translation error:  0.024589786938990412
# --- 12.242002487182617 seconds ---
# Epoch: [1/20], Batch: 14, Loss: 0.009639544804104627
# feature extraction time:  5.9920878410339355
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694345474243164
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009965896606445312
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2477, 7253, 1036,  ..., 2513, 2752, 2524], device='cuda:0')
# get_cat_feat_tgt time:  0.08571386337280273
# Loss: 0.006812624345002246
# rotation error:  0.38716193277726313
# translation error:  0.017844268424327663
# --- 12.572579145431519 seconds ---
# feature extraction time:  6.245768785476685
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020891189575195312
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5756, 1471, 1297,  ..., 1895, 6472,  138], device='cuda:0')
# get_cat_feat_tgt time:  0.09382009506225586
# Loss: 0.004124522576254514
# rotation error:  1.4796432668795503
# translation error:  0.01568927159287531
# --- 12.703383922576904 seconds ---
# feature extraction time:  6.686838150024414
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793980598449707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2942, 2328, 2511,  ..., 7469, 4839, 3952], device='cuda:0')
# get_cat_feat_tgt time:  0.09069681167602539
# Loss: 0.0038397763107092704
# rotation error:  0.8456273407264824
# translation error:  0.010217778665514656
# --- 13.2309410572052 seconds ---
# feature extraction time:  6.406563997268677
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939090728759766
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6703,  543, 3638,  ..., 1354, 4043, 6972], device='cuda:0')
# get_cat_feat_tgt time:  0.09867048263549805
# Loss: 0.0063910632584177115
# rotation error:  2.408005982710132
# translation error:  0.016318751874943478
# --- 13.164950609207153 seconds ---
# feature extraction time:  6.425500392913818
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.018937110900878906
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1990, 1783, 9479,  ..., 8658, 3061, 1441], device='cuda:0')
# get_cat_feat_tgt time:  0.09621930122375488
# Loss: 0.005584540724610499
# rotation error:  0.4559444069779715
# translation error:  0.01593250157712452
# --- 13.346847534179688 seconds ---
# Epoch: [1/20], Batch: 19, Loss: 0.005584540724610499
# feature extraction time:  6.5332770347595215
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694321632385254
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3583, 2351, 1748,  ..., 3337, 6507, 6642], device='cuda:0')
# get_cat_feat_tgt time:  0.09069705009460449
# Loss: 0.006987623331510385
# rotation error:  0.659429655219851
# translation error:  0.020310407924234095
# --- 13.021718263626099 seconds ---
# feature extraction time:  6.432506799697876
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017939329147338867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009970664978027344
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9356, 5737,  528,  ..., 8210, 7356, 8530], device='cuda:0')
# get_cat_feat_tgt time:  0.11461687088012695
# Loss: 0.0039159781820405914
# rotation error:  0.939677178673625
# translation error:  0.014270493900177542
# --- 12.963863849639893 seconds ---
# feature extraction time:  7.010636329650879
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694345474243164
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2666, 2042, 1380,  ..., 8091,  142, 9750], device='cuda:0')
# get_cat_feat_tgt time:  0.10092926025390625
# Loss: 0.008605494056617162
# rotation error:  0.9735583897811109
# translation error:  0.016095353161709774
# --- 13.142389297485352 seconds ---
# feature extraction time:  6.281164884567261
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016943693161010742
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009963512420654297
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 592, 1589, 9888,  ..., 9865, 7448, 5060], device='cuda:0')
# get_cat_feat_tgt time:  0.10464954376220703
# Loss: 0.008424642490947756
# rotation error:  1.169894160713654
# translation error:  0.0150887180523013
# --- 13.255685806274414 seconds ---
# feature extraction time:  6.046767473220825
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940044403076172
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6424, 4485, 6941,  ..., 9679, 1824, 5416], device='cuda:0')
# get_cat_feat_tgt time:  0.08969998359680176
# Loss: 0.009114325444638782
# rotation error:  1.0668464341584782
# translation error:  0.019966247649506927
# --- 13.177027463912964 seconds ---
# Epoch: [1/20], Batch: 24, Loss: 0.009114325444638782
# feature extraction time:  6.947752475738525
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.022923707962036133
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([3815, 6045, 6248,  ..., 6526, 7157, 2438], device='cuda:0')
# get_cat_feat_tgt time:  0.12059736251831055
# Loss: 0.01046546089664701
# rotation error:  1.0103762060111772
# translation error:  0.02206793205704403
# --- 13.601489067077637 seconds ---
# feature extraction time:  6.779316425323486
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940282821655273
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009968280792236328
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([6662, 9497, 6405,  ..., 9177, 1214, 5422], device='cuda:0')
# get_cat_feat_tgt time:  0.09468340873718262
# Loss: 0.005109277972420442
# rotation error:  0.9554718774973062
# translation error:  0.0165728786158145
# --- 13.12734580039978 seconds ---
# feature extraction time:  6.214207887649536
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793980598449707
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5427, 2528, 3506,  ...,  735, 9542,   25], device='cuda:0')
# get_cat_feat_tgt time:  0.07973337173461914
# Loss: 0.006112456657149736
# rotation error:  1.400786606331234
# translation error:  0.015955621318939253
# --- 13.197840452194214 seconds ---
# feature extraction time:  5.823513984680176
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.014950037002563477
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1435,  310, 7101,  ..., 4080, 6092, 5397], device='cuda:0')
# get_cat_feat_tgt time:  0.09368681907653809
# Loss: 0.010054687501910681
# rotation error:  1.770192278142678
# translation error:  0.019424923177035626
# --- 12.160311222076416 seconds ---
# feature extraction time:  6.500250816345215
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793956756591797
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
#  10%|█         | 2/20 [13:07<1:58:14, 394.12s/it]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4590, 5505, 2842,  ...,  793, 8591,  451], device='cuda:0')
# get_cat_feat_tgt time:  0.09966659545898438
# Loss: 0.009523812904433859
# rotation error:  1.6035487633886156
# translation error:  0.018287188696785053
# --- 13.188870191574097 seconds ---
# Epoch: [1/20], Batch: 29, Loss: 0.009523812904433859
# loss epoch [0.008218081927973762, 0.004211456075801618, 0.0033743481419934067, 0.007655996853436484, 0.008112031264531635, 0.007811046140674535, 0.0041859663373815335, 0.006882031127524826, 0.008104870044218476, 0.00795531342780694, 0.009281226642050933, 0.005748528923793285, 0.004287760735529958, 0.007166221533380425, 0.009639544804104627, 0.006812624345002246, 0.004124522576254514, 0.0038397763107092704, 0.0063910632584177115, 0.005584540724610499, 0.006987623331510385, 0.0039159781820405914, 0.008605494056617162, 0.008424642490947756, 0.009114325444638782, 0.01046546089664701, 0.005109277972420442, 0.006112456657149736, 0.010054687501910681, 0.009523812904433859]
# epoch #2
# feature extraction time:  6.8103649616241455
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020932435989379883
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9837, 8678, 7087,  ...,  711, 6802, 9581], device='cuda:0')
# get_cat_feat_tgt time:  0.10392975807189941
# Loss: 0.008156840456064782
# rotation error:  1.6901462682021453
# translation error:  0.01900259981576222
# --- 13.312148571014404 seconds ---
# feature extraction time:  6.8979198932647705
# ...
# rotation error:  54.077676639304165
# translation error:  0.03320898486224581
# --- 13.33854079246521 seconds ---
# Epoch: [19/20], Batch: 9, Loss: 0.020479908945930863
# feature extraction time:  6.603057146072388
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020930051803588867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 993, 5193, 9114,  ..., 3222, 5497, 5593], device='cuda:0')
# get_cat_feat_tgt time:  0.09867024421691895
# Loss: 0.015226771188028633
# rotation error:  298.12400867200586
# translation error:  0.03308260162568089
# --- 13.101924180984497 seconds ---
# feature extraction time:  6.141679048538208
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694321632385254
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009965896606445312
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([2182, 7306, 1761,  ..., 9332, 5873, 6141], device='cuda:0')
# get_cat_feat_tgt time:  0.09169387817382812
# Loss: 0.026073182897309914
# rotation error:  88.60127141553174
# translation error:  0.020520988771623186
# --- 12.898232460021973 seconds ---
# feature extraction time:  6.6747682094573975
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016924142837524414
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8838, 7552, 6709,  ..., 4932, 2438, 6234], device='cuda:0')
# get_cat_feat_tgt time:  0.08670997619628906
# Loss: 0.020838413084548285
# rotation error:  37.64477676308524
# translation error:  0.020320751882439873
# --- 13.278989315032959 seconds ---
# feature extraction time:  6.586105823516846
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694345474243164
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009970664978027344
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4781, 1398, 3085,  ..., 9993, 7617, 1974], device='cuda:0')
# get_cat_feat_tgt time:  0.10564684867858887
# Loss: 0.016122840347331045
# rotation error:  41.248859569097334
# translation error:  0.017207260732450987
# --- 13.612609386444092 seconds ---
# feature extraction time:  6.844715595245361
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.0219268798828125
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1246, 4609, 3898,  ..., 4848, 1340, 6339], device='cuda:0')
# get_cat_feat_tgt time:  0.09209561347961426
# Loss: 0.013217706228020838
# rotation error:  29.732062958943562
# translation error:  0.010305242774811
# --- 13.47708249092102 seconds ---
# Epoch: [19/20], Batch: 14, Loss: 0.013217706228020838
# feature extraction time:  6.78159761428833
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020929813385009766
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4826, 4524, 1939,  ..., 1481, 7184, 3812], device='cuda:0')
# get_cat_feat_tgt time:  0.0890359878540039
# Loss: 0.010255050661525617
# rotation error:  48.221513405993285
# translation error:  0.014809289269662318
# --- 13.246407747268677 seconds ---
# feature extraction time:  6.3597328662872314
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020930051803588867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 580, 9274, 6609,  ..., 1981, 1344, 5511], device='cuda:0')
# get_cat_feat_tgt time:  0.09966683387756348
# Loss: 0.023686653465880555
# rotation error:  37.75388086485933
# translation error:  0.010871205669224069
# --- 13.226917266845703 seconds ---
# feature extraction time:  6.776340961456299
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694321632385254
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([4441, 4481, 9517,  ..., 9222, 5176, 5154], device='cuda:0')
# get_cat_feat_tgt time:  0.08671021461486816
# Loss: 0.020038702524214073
# rotation error:  36.072064845139444
# translation error:  0.0138668581546112
# --- 13.873608112335205 seconds ---
# feature extraction time:  6.871026277542114
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.017940044403076172
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8602, 9169, 1862,  ..., 4337, 8348, 2853], device='cuda:0')
# get_cat_feat_tgt time:  0.08881545066833496
# Loss: 0.02482146924131238
# rotation error:  285.0366904254157
# translation error:  0.022702827639424338
# --- 13.472007751464844 seconds ---
# feature extraction time:  6.516263246536255
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01793956756591797
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8712,  358, 7859,  ..., 5045, 8897, 9191], device='cuda:0')
# get_cat_feat_tgt time:  0.09108591079711914
# Loss: 0.013615765945689588
# rotation error:  25.15223882988279
# translation error:  0.023975757355194888
# --- 13.486956596374512 seconds ---
# Epoch: [19/20], Batch: 19, Loss: 0.013615765945689588
# feature extraction time:  6.6757471561431885
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020930051803588867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1486, 1667,  918,  ..., 1833, 2212, 5415], device='cuda:0')
# get_cat_feat_tgt time:  0.07886195182800293
# Loss: 0.012438701608713952
# rotation error:  10.386979497458103
# translation error:  0.02744325172067692
# --- 13.432469606399536 seconds ---
# feature extraction time:  6.355849027633667
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01694321632385254
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0009968280792236328
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([   1,  584,  960,  ..., 1985, 4386, 1499], device='cuda:0')
# get_cat_feat_tgt time:  0.0980229377746582
# Loss: 0.01682508606825008
# rotation error:  41.17461152892519
# translation error:  0.028287735136927866
# --- 13.355381488800049 seconds ---
# feature extraction time:  6.787433624267578
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020930051803588867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([5325, 5043, 6379,  ..., 2611, 4858, 6101], device='cuda:0')
# get_cat_feat_tgt time:  0.08970022201538086
# Loss: 0.0343984693220931
# rotation error:  84.43327342046628
# translation error:  0.03383780017150189
# --- 13.608911514282227 seconds ---
# feature extraction time:  6.671777248382568
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.015946388244628906
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([9823, 7600, 8780,  ..., 4282, 8963,  211], device='cuda:0')
# get_cat_feat_tgt time:  0.10031580924987793
# Loss: 0.018461748276267544
# rotation error:  5.12770159121777
# translation error:  0.0317090330630677
# --- 13.067046403884888 seconds ---
# feature extraction time:  6.898930549621582
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020929813385009766
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7549, 2614, 9254,  ..., 2754, 9299, 1498], device='cuda:0')
# get_cat_feat_tgt time:  0.1006631851196289
# Loss: 0.036638351773751014
# rotation error:  90.83351353236458
# translation error:  0.027697672814626813
# --- 13.669665575027466 seconds ---
# Epoch: [19/20], Batch: 24, Loss: 0.036638351773751014
# feature extraction time:  6.6737587451934814
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.023920297622680664
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([7147, 8461, 3880,  ..., 5305, 3401, 2931], device='cuda:0')
# get_cat_feat_tgt time:  0.10393524169921875
# Loss: 0.01133872390411535
# rotation error:  44.044157202737416
# translation error:  0.01977972489716096
# --- 13.120450735092163 seconds ---
# feature extraction time:  6.667703628540039
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.019933223724365234
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8303,  427,  674,  ..., 7575, 9977, 1335], device='cuda:0')
# get_cat_feat_tgt time:  0.09894251823425293
# Loss: 0.01660561530924419
# rotation error:  34.91963961295754
# translation error:  0.02717241014028524
# --- 13.298932075500488 seconds ---
# feature extraction time:  6.7874040603637695
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.020930051803588867
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([8829, 1510, 9626,  ..., 8728, 8350, 2074], device='cuda:0')
# get_cat_feat_tgt time:  0.11579418182373047
# Loss: 0.027343001070841835
# rotation error:  37.959373384205136
# translation error:  0.02717341285941964
# --- 13.781312465667725 seconds ---
# feature extraction time:  6.256079196929932
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.01697254180908203
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([1887,  636, 9181,  ..., 9034, 5648, 6007], device='cuda:0')
# get_cat_feat_tgt time:  0.08836793899536133
# Loss: 0.04634827570689612
# rotation error:  50.03254441933357
# translation error:  0.03262684712307795
# --- 13.020811557769775 seconds ---
# feature extraction time:  6.6630425453186035
# src_keypts_idx_unsqueezed:  torch.Size([1, 3, 64])
# src_keypts:  torch.Size([1, 64, 3])
# Grouping keypoints time:  0.016943693161010742
# B:  1
# K_topk:  64
# nsample:  32
# num_feat:  32
# get_cat_feat_src time:  0.0
# 100%|██████████| 20/20 [2:12:48<00:00, 398.45s/it]
# tgt_pts_xyz:  torch.Size([1, 10000, 3])
# ref_pts:  torch.Size([1, 10000, 3])
# dist_normalize:  torch.Size([1, 32, 13824])
# feat_weight_map:  torch.Size([1, 32, 32, 13824])
# idx_1_mask:  tensor([[0]])
# idx_1_mask_flatten:  tensor([0])
# idx_2_mask:  tensor([ 333, 8645, 2555,  ..., 2304, 2051,  859], device='cuda:0')
# get_cat_feat_tgt time:  0.08765649795532227
# Loss: 0.00925053492557177
# rotation error:  25.303267896419555
# translation error:  0.033886668592071414
# --- 13.021884679794312 seconds ---
# Epoch: [19/20], Batch: 29, Loss: 0.00925053492557177
# loss epoch [0.019930899763159, 0.018847588280161913, 0.022835652000832582, 0.02876474134440855, 0.03217326517464673, 0.017569888328435722, 0.015523842212944151, 0.010062925407132235, 0.029266787283699768, 0.020479908945930863, 0.015226771188028633, 0.026073182897309914, 0.020838413084548285, 0.016122840347331045, 0.013217706228020838, 0.010255050661525617, 0.023686653465880555, 0.020038702524214073, 0.02482146924131238, 0.013615765945689588, 0.012438701608713952, 0.01682508606825008, 0.0343984693220931, 0.018461748276267544, 0.036638351773751014, 0.01133872390411535, 0.01660561530924419, 0.027343001070841835, 0.04634827570689612, 0.00925053492557177]

# %%
# save
print("Finished Training")
# Out:
# Finished Training
